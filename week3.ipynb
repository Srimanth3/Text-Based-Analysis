# %% [markdown]
# # **ClassWork on 01/24/2024**

# %% [markdown]
# ## **Loading the DataSet**

# %%
# Loading Data set using pandas.
import pandas as pd  # Importing pandas as pd
file="C:/Users/srima/Desktop/Text based Analysis/un-general-debates-blueprint.csv" # File Path
df=pd.read_csv(file)
# Using head Meathod to Print Top 20 Rows
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %% [markdown]
# ## **Data Pre-Processing**

# %% [markdown]
# ### **Printing column Names**

# %%
# Printing Column Names 
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# ### **Printing Data Types of Columns**

# %%
# Printing Data Types of the Columns
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# ### **Applying Info Method**

# %%
# Printing the Basic Information of the Data Set.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# ### **Printing Statistical Information**

# %%
# Printing the Statistical Information of the Data Set.
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# ### **Adding a New Column**

# %%
## Adding a new column to store length of the text.
df['length']=df['text'].str.len()
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# ### **Applying describr Methid**

# %%
# Using describe Method
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# ### **Checking for Missing Data**

# %%
# Replacing Missing Data with "unknown"
df['speaker'] = df['speaker'].fillna('unknown')
df['position'] = df['position'].fillna('unknown')
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# ### **Changing Columns to UpperCase**

# %%
# Changing Columns to UpperCase
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()

# %%
# Speakers with BUSH instance in them    
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# ...

# %% [markdown]
# ## **Data Visuailazation**

# %%
# Importing matplotlib Package
import matplotlib.pyplot as plt
# Assuming 'length' as a Target Column
df['length'].plot(label='Length')
# Adding legend
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.legend()
# Display the plot
plt.show()

# %% [markdown]
# ### **Ploating a Box PLot**

# %%
df['length'].plot(kind='box', vert=False)
# Adding labels and title
plt.xlabel('Length')
plt.title('Horizontal Box Plot of Length')
# Showing the plot
plt.show()

# %% [markdown]
# ### **Creating a Histogram**

# %%
# Creating a Histogram
df['length'].plot(kind='hist',bins=30)
plt.xlabel('Length')
# Out:
# Text(0.5, 0, 'Length')

# %% [markdown]
# ### **Applying Seaborn Package**

# %%
# Importing Seaborn Package
import seaborn as sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box') # Ploating a Box Plot
g.fig.set_size_inches(10, 8) # Describe the size of Plot
# Out:
# C:\Users\srima\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ## **Pre-Processing Pipeline**

# %%
# !pip install regex
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Regex to Pull Out Words
import regex as re
def tokenize(text):return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text) # Function To Tokenize

# %% [markdown]
# ### **Toknizing the Given Text**

# %%
# Toknizing the Given Text
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ### **Using nltk Package**

# %%
# Installing nltk Package
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk  # Importing nltk Package
from nltk.tokenize import word_tokenize

nltk.download('punkt') 
nltk.download('stopwords')
# Downloading list of English Stop Words
stopwords = set(nltk.corpus.stopwords.words('english'))  
print(stopwords)
# Out:
# {'his', 'ain', 'were', 'just', "you'd", 'him', "that'll", 'when', 'no', 'can', 'again', 'yours', 'below', 'was', 'down', "hasn't", 'there', 'through', 'herself', 'with', 'hasn', "mightn't", "wasn't", 'as', 'are', 'from', 'but', "don't", "mustn't", 'out', 'into', 'only', 'mustn', 'isn', 'be', 'himself', 'above', "hadn't", 'm', 'up', 'we', 'ours', 'will', 'further', 'ourselves', 're', "she's", 'too', 'our', 'having', 'by', 'what', 'if', 'have', "you've", 'theirs', 'couldn', 'them', 'while', 'any', 'these', 'should', 'here', 'than', "won't", 'y', 'why', 'this', 'haven', 'over', "isn't", 'your', 'mightn', 'for', 'weren', 'who', 'until', 'after', "couldn't", 'he', 'themselves', 'needn', 'so', 'each', 'same', 'wasn', 'during', 'she', 'nor', 'is', 'few', 'to', 'me', 'about', 'own', "doesn't", 'very', 'on', 'o', 'of', 'myself', 'aren', 'those', 'under', "weren't", 'don', "should've", "you'll", 'does', 'you', 'being', 'yourself', 'won', 'did', 'hadn', 'most', "you're", 'an', 'or', 'her', 'off
# ...

# %% [markdown]
# ### **Making a PipeLine**

# %%
# making a “pipeline"
pipeline = [str.lower, tokenize]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ### **Runing PipeLine**

# %%
# Runing the pipeline
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ### **Cunting Tokens**

# %%
#counting the tokens
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length  \
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
# ...

# %% [markdown]
# ## **Word Frequency Analysis**

# %%
from collections import Counter # Importing Counter from Collections
tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens) # Counting tokens
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ### **Adding New Data**

# %%
# Adding New Data to the Current Count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ### **Counting Word Repetations**

# %%
# Counting the Word Repetations
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('the', 1899342), ('of', 1157244), ('and', 796563), ('to', 734634), ('in', 523189)]

# %%
# Using word frequency in it’s own dataframe for analysis
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq']) 
freq_df = freq_df.query('freq >= 1') # Use it to Prevent Worlds that are infrequent
freq_df.index.name = 'token'

# %% [markdown]
# ### **Sorting Based on Frequency**

# %%
# Let,s sort Based on Frequency and display
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#           freq
# token
# the    1899342
# of     1157244
# and     796563
# to      734634
# in      523189
# a       340295
# that    314521
# is      241744
# for     230185
# we      220322

# %% [markdown]
# ### **Printing Statistical Data**

# %%
# Printing the Statistical Data
freq_df.describe()
# Out:
#                freq
# count  6.844800e+04
# mean   3.118536e+02
# std    1.028325e+04
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    1.500000e+01
# max    1.899342e+06

# %% [markdown]
# ### **Aplying Bar Chat**

# %%
# Bar chart 
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8)) # Only for Top 15 Words
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words') # Legend
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
# Installing Wordcloud Package
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### **Creating WordCloud**

# %%
# Creating WordCloud
from wordcloud import WordCloud # Importing WordCloud Package
from matplotlib import pyplot as plt # Importing Pyplot Package as plt
text = df.query("year==2015 and country=='USA'")['text'].values[0] # Only for USA
plt.figure(figsize=(14, 7)) 
wc = WordCloud(max_words=100, stopwords=stopwords) # Max Words to Display are 100
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='Black', width = 300, height=300, max_words=100, margin=2) # Giving BackGround Colour .
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None) # Giving fig Size
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
